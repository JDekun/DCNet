# %% [markdown]
# ##### 1、 更改原backbone的分类头后，训练新的主干网络 epoch(0-20)  [wandb 48]

# %%
# %%time
import os, sys, datetime; os.chdir("/".join(sys.path[0].split('/')[:-1]))
dir_date = "./experiment/result/newfcn/results{}".format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
result_data = dir_date; result_log = dir_date + ".log"; print(dir_date)

# !CUDA_VISIBLE_DEVICES=4,5 torchrun --nproc_per_node=2 train_multi_GPU.py \
    --wandb True --wandb_model run \
    --sync_bn False --amp True --aux True \
    --batch_size 16 --batch_size_val 8 \
    --epochs 20 --contrast False\
    --model_name dcnet_resnet50 --loss_name intra\
    --result_save $result_data\
    2>&1 | tee $result_log
# Out:
# ./experiment/result/newfcn/results20221115-183922
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# ...

# %% [markdown]
# ##### 2、resume 20 -> 40   [wandb 57]

# %%
# %%time
experiment_name = "newfcn"
import os, sys, datetime; os.chdir("/".join(sys.path[0].split('/')[:-1]))
name_date= "{}/{}".format(experiment_name, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
dir_log = "./experiment/result/{}.log".format(name_date);  print(dir_log)

# !CUDA_VISIBLE_DEVICES=4,5 torchrun --nproc_per_node=2 train_multi_GPU.py \
    --wandb True --wandb_model run \
    --sync_bn False --amp True --aux True \
    --batch_size 16 --batch_size_val 8 \
    --epochs 40 --start_epoch 20 --contrast False \
    --model_name dcnet_resnet50 --loss_name intra \
    --resume checkpoint/newfcn/20221115-183922/model_19.pth \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# ./experiment/result/newfcn/20221116-135402.log
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# ...

# %% [markdown]
# ##### resume 40 -> 60  [wandb 59]

# %%
# %%time
experiment_name = "newfcn"
import os, sys, datetime; os.chdir("/".join(sys.path[0].split('/')[:-1]))
name_date= "{}/{}".format(experiment_name, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
dir_log = "./experiment/result/{}.log".format(name_date);  print(dir_log)

# !CUDA_VISIBLE_DEVICES=4,5 torchrun --nproc_per_node=2 train_multi_GPU.py \
    --wandb True --wandb_model run \
    --sync_bn False --amp True --aux True \
    --batch_size 16 --batch_size_val 8 \
    --epochs 60 --start_epoch 40 --contrast False \
    --model_name dcnet_resnet50 --loss_name intra \
    --resume checkpoint/newfcn/20221116-135402/model_39.pth \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# ./experiment/result/newfcn/20221116-155907.log
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# ...
