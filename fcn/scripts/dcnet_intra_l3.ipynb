# %% [markdown]
# ### [intra-l3u-16](https://wandb.ai/dekun/DCNet/runs/388x5src)
# >`mIOU 67.316` find_unused_parameters=False

# %%
# !experiment_name="dcnet_intra_l3";cd ../ ;\
    name_date="${experiment_name}/$(date +%Y-%m%d-%H%M%S)";\
    dir="./results/${name_date}";mkdir -p ${dir};dir_log="${dir}/output.log";\
CUDA_VISIBLE_DEVICES=3,4,5,7 torchrun --nproc_per_node=4 train_multi_GPU.py \
    --wandb True --wandb_model run --sync_bn False --amp True --aux False \
    --batch_size 12 --batch_size_val 8 \
    --epochs 20 --start_epoch 0 \
    --contrast True \
    --model_name dcnet_resnet50 --pre_trained bk-DCNet-8-e20 \
    --loss_name intra \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 3): env://
# | distributed init (rank 2): env://
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# dcnet_intra_l3/2022-1121-164801
# ...

# %% [markdown]
# ### [intra-l3u-un_param-14](https://wandb.ai/dekun/DCNet/runs/1opetmh7)
# >`mIOU 67.083` find_unused_parameters=True （会影响perform）

# %%
# !experiment_name="dcnet_intra_l3";cd ../ ;\
    name_date="${experiment_name}/$(date +%Y-%m%d-%H%M%S)";\
    dir="./results/${name_date}";mkdir -p ${dir};dir_log="${dir}/output.log";\
CUDA_VISIBLE_DEVICES=3,4,5,7 torchrun --nproc_per_node=4 train_multi_GPU.py \
    --wandb True --wandb_model run --sync_bn False --amp True --aux False \
    --batch_size 12 --batch_size_val 8 \
    --epochs 20 --start_epoch 0 \
    --contrast True\
    --model_name dcnet_resnet50 --pre_trained bk-DCNet-8-e20 \
    --loss_name intra \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 2): env://
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# | distributed init (rank 3): env://
# dcnet_intra_l3/2022-1121-143718
# ...

# %% [markdown]
# ### [intra-l3d-13](https://wandb.ai/dekun/DCNet/runs/qkshqhmt)
# >`mIOU 67.32`2 效果好那么一点，曲线平滑一点，总的来说结果较好

# %%
# !experiment_name="dcnet_intra_l3";cd ../ ;\
    name_date="${experiment_name}/$(date +%Y-%m%d-%H%M%S)";\
    dir="./results/${name_date}";mkdir -p ${dir};dir_log="${dir}/output.log";\
CUDA_VISIBLE_DEVICES=3,4,5,7 torchrun --nproc_per_node=4 train_multi_GPU.py \
    --wandb True --wandb_model run --sync_bn False --amp True --aux False \
    --batch_size 12 --batch_size_val 8 \
    --epochs 20 --start_epoch 0 \
    --contrast True\
    --model_name dcnet_resnet50 --pre_trained bk-DCNet-8-e20 \
    --loss_name intra \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 3): env://
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# | distributed init (rank 2): env://
# dcnet_intra_l3/2022-1121-131506
# ...

# %% [markdown]
# ## 使用aux辅助intra-l3训练 实验

# %% [markdown]
# ### 是否需要aux的权重
# >训练好backbone后`aux需要去掉(权重)`，权重只取主干和分类头部分，`否则在训练新网络时会损害模型`

# %% [markdown]
# #### [intra-l3_aux-dcnet-12](https://wandb.ai/dekun/DCNet/runs/10i0fkgw) 使用bk-DCNet-8-e20权重(`有aux，没权重`) intra_l3层内对比

# %%
# !experiment_name="dcnet_intra_l3";cd ../ ;\
    name_date="${experiment_name}/$(date +%Y-%m%d-%H%M%S)";\
    dir="./results/${name_date}";mkdir -p ${dir};dir_log="${dir}/output.log";\
CUDA_VISIBLE_DEVICES=3,4,5,7 torchrun --nproc_per_node=4 train_multi_GPU.py \
    --wandb True --wandb_model run --sync_bn False --amp True --aux True \
    --batch_size 12 --batch_size_val 8 \
    --epochs 20 --start_epoch 0 \
    --contrast True\
    --model_name dcnet_resnet50 --pre_trained bk-DCNet-8-e20 \
    --loss_name intra \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 3): env://
# | distributed init (rank 2): env://
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# fcn_backbone/2022-1121-114144
# ...

# %% [markdown]
# #### [intra-l3_aux-dcnet_aux-11](https://wandb.ai/dekun/DCNet/runs/1gbwkc67) 使用bk-DCNet-aux-7-e20权重(`有aux，有权重`) intra_l3层内对比

# %%
# !experiment_name="dcnet_intra_l3";cd ../ ;\
    name_date="${experiment_name}/$(date +%Y-%m%d-%H%M%S)";\
    dir="./results/${name_date}";mkdir -p ${dir};dir_log="${dir}/output.log";\
CUDA_VISIBLE_DEVICES=3,4,5,7 torchrun --nproc_per_node=4 train_multi_GPU.py \
    --wandb True --wandb_model run --sync_bn False --amp True --aux True \
    --batch_size 12 --batch_size_val 8 \
    --epochs 20 --start_epoch 0 \
    --contrast True\
    --model_name dcnet_resnet50 --pre_trained bk-DCNet-aux-7-e20 \
    --loss_name intra \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 2): env://
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# | distributed init (rank 3): env://
# fcn_backbone/2022-1121-103502
# ...

# %% [markdown]
# ### 是否需要classifier权重
# >`需要预训练好的classifer权重`, 否则效果非常差

# %% [markdown]
# #### [intra-l3_aux-fcn_coco-10](https://wandb.ai/dekun/DCNet/runs/2v8o8ra2) 使用fcn_resnet50_coco权重（`不包括classifier的权重`，有aux权重） intra_l3层内对比

# %%
# !experiment_name="dcnet_intra_l3";cd ../ ;\
    name_date="${experiment_name}/$(date +%Y-%m%d-%H%M%S)";\
    dir="./results/${name_date}";mkdir -p ${dir};dir_log="${dir}/output.log";\
CUDA_VISIBLE_DEVICES=3,4,5,7 torchrun --nproc_per_node=4 train_multi_GPU.py \
    --wandb True --wandb_model run --sync_bn False --amp True --aux True \
    --batch_size 12 --batch_size_val 8 \
    --epochs 20 --start_epoch 0 \
    --contrast True\
    --model_name dcnet_resnet50 --pre_trained fcn_resnet50_coco \
    --loss_name intra \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 2): env://
# | distributed init (rank 1): env://
# | distributed init (rank 3): env://
# | distributed init (rank 0): env://
# fcn_backbone/2022-1121-093207
# ...
