# %%
# !experiment_name="mep";cd ../ ;\
    name_date="${experiment_name}/$(date +%Y-%m%d-%H%M%S)";\
    dir="./results/${name_date}";mkdir -p ${dir};dir_log="${dir}/output.log";\
CUDA_VISIBLE_DEVICES=1,2,3,4 torchrun --nproc_per_node=4 --master_port=12243 train_multi_GPU.py \
    --wandb DCNet_city --wandb_model dryrun --sync_bn True --amp True --aux True \
    --model_name mep_res_101 --project_dim 256 --pre_trained resnet101-imagenet.pth --data_path cityscapes \
    --epochs 50 --batch_size 2 --batch_size_val 1 --memory_size 4096 \
    --contrast 0 --L1_loss 0.1 --L2_loss 0.1 --L3_loss 0.1 --loss_name aspp_loss \
    --sample weight_ade_8 --attention cbam \
    --name_date $name_date \
    2>&1 | tee $dir_log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 3): env://
# | distributed init (rank 1): env://
# | distributed init (rank 2): env://
# mep/2023-0420-215351
# ...
