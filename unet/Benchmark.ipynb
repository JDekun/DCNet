# %%
# UNet Best mIOU
#  200 epoch: 81.5     
# 1000 epoch: 81.9

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4  --amp --sync_bn True \
                                   --model_name UNet \
                                   --epochs 1000 \
                                   --with_contrast -1  \
                                2>&1 | tee ./output/output.log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=1000, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=-1, model_name='UNet', loss_name='double', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# ...

# %%
# VGG16UNet Best mIOU
# 200  epoch: 81.0
# 1000 epoch: 81.6

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4  --amp --sync_bn True \
                                   --model_name VGG16UNet \
                                   --epochs 1000 \
                                   --with_contrast -1  \
                                2>&1 | tee ./output/output.log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# /home/zk/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/zk/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...

# %%
# MobileV3Unet Best mIOU
#  200 epoch: 57.9
# 1000 epoch: 77.7

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4  --amp --sync_bn True \
                                   --model_name MobileV3Unet \
                                   --epochs 1000 \
                                   --with_contrast -1  \
                                2>&1 | tee ./output/output.log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# /home/zk/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/zk/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...
