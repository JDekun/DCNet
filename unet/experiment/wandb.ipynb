# %%
import os
os.chdir('../')

# %%
# Best mIOU 

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 train_multi_GPU.py \
    --wandb True --wandb_model run \
    --amp True --sync_bn True \
    --batch_size 4 --batch_size 4\
    --epochs 200 \
    --model_name UNet --loss_name segloss\
    --with_contrast -1  \
   2>&1 | tee ./experiment/output.log 

# Benchmark UNet
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, batch_size_val=2, start_epoch=0, epochs=200, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=-1, model_name='UNet', loss_name='segloss', seed=1, wandb=True, wandb_model='run', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# ...

# %%
# Best mIOU 

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 train_multi_GPU.py \
    --wandb True --wandb_model run \
    --amp --sync_bn True \
    --batch_size 4 --batch_size 4\
    --epochs 200 \
    --model_name DC_UNet --loss_name intra\
    --with_contrast 40  \
   2>&1 | tee ./experiment/output.log 

# Benchmark DC_UNet intra
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, batch_size_val=2, start_epoch=0, epochs=200, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DC_UNet', loss_name='intra', seed=1, wandb=True, wandb_model='run', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# ...

# %%
# Best mIOU 

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 train_multi_GPU.py \
    --wandb True --wandb_model run \
    --amp --sync_bn True \
    --batch_size 4 --batch_size 4\
    --epochs 200 \
    --model_name DC_UNet --loss_name inter\
    --with_contrast 40  \
   2>&1 | tee ./experiment/output.log 

# Benchmark DC_UNet inter
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, batch_size_val=2, start_epoch=0, epochs=200, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DC_UNet', loss_name='inter', seed=1, wandb=True, wandb_model='run', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# ...

# %%
# Best mIOU 

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 train_multi_GPU.py \
    --wandb True --wandb_model run \
    --amp --sync_bn True \
    --batch_size 4 --batch_size 4\
    --epochs 200 \
    --model_name DC_UNet --loss_name double\
    --with_contrast 40  \
   2>&1 | tee ./experiment/output.log 

# Benchmark UNet diuble
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, batch_size_val=2, start_epoch=0, epochs=200, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DC_UNet', loss_name='double', seed=1, wandb=True, wandb_model='run', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# ...
