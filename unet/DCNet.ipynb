# %% [markdown]
# ### 基线

# %%
# mIOU 72.7

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4  --amp --sync_bn True \
                                   --model_name DCNet \
                                   --epochs 200 \
                                   --with_contrast -1  \
                                2>&1 | tee ./output/output.log 
# 增大epoch 200->1000、设置不同GPU上的捡BN同步
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=200, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=-1, model_name='DCNet', loss_name='double', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# ...

# %% [markdown]
# ### 层内对比

# %%
# mIOU 72.7 -> 73.2

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4  --amp --sync_bn True\
                                   --model_name DCNet \
                                   --epochs 200 \
                                   --with_contrast 40  \
                                   --loss_name intra \
                                   --layer_loss 0.1 0.1 0.05 0.01 \
                                 2>&1 | tee ./output/output.log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=200, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DCNet', loss_name='intra', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# ...

# %%
# mIOU 72.7 -> 79.4

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4  --amp --sync_bn True\
                                   --model_name DCNet \
                                   --epochs 1000 \
                                   --with_contrast 40  \
                                   --loss_name intra \
                                   --layer_loss 0.1 0.1 0.05 0.01 \
                                 2>&1 | tee ./output/output.log 
# 增大epoch 200->1000
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=1000, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DCNet', loss_name='intra', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# ...

# %% [markdown]
# ### 层间对比

# %%
# mIOU 72.7 -> 77.7

# !CUDA_VISIBLE_DEVICES=6 torchrun --nproc_per_node=1 \
                train_multi_GPU.py --b 4  --amp --sync_bn False\
                                   --model_name DCNet \
                                   --epochs 200 \
                                   --with_contrast 40  \
                                   --loss_name inter \
                                   --layer_loss 0.1 0.1 0.05 0.01 \
                                 2>&1 | tee ./output/output.log
# Out:
# | distributed init (rank 0): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=200, sync_bn=False, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=1, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DCNet', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# Epoch: [0]  [0/5]  eta: 0:00:17  lr: 0.002008  loss: 1.3320 (1.3320)  time: 3.4177  data: 0.4781  max mem: 3504
# Epoch: [0]  [1/5]  eta: 0:00:07  lr: 0.004006  loss: 1.3117 (1.3218)  time: 1.9038  data: 0.2407  max mem: 3717
# Epoch: [0]  [2/5]  eta: 0:00:04  lr: 0.006004  loss: 1.3454 (1.3297)  time: 1.3985  data: 0.1628  max mem: 3718
# Epoch: [0]  [3/5]  eta: 0:00:02  lr: 0.008002  loss: 1.2775 (1.3166)  time: 1.1471  data: 0.1231  max mem: 3718
# ...

# %%
# mIOU 77.7 -> 80.7

# !CUDA_VISIBLE_DEVICES=6 torchrun --nproc_per_node=1 \
                train_multi_GPU.py --b 4  --amp --sync_bn False\
                                   --model_name DCNet \
                                   --epochs 1000 \
                                   --with_contrast 40  \
                                   --loss_name inter \
                                   --layer_loss 0.1 0.1 0.05 0.01 \
                                 2>&1 | tee ./output/output.log 
# 增大epoch 200->1000
# Out:
# | distributed init (rank 0): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=1000, sync_bn=False, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=1, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DCNet', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# Epoch: [0]  [0/5]  eta: 0:00:17  lr: 0.002008  loss: 1.2366 (1.2366)  time: 3.4163  data: 0.4571  max mem: 3504
# Epoch: [0]  [1/5]  eta: 0:00:07  lr: 0.004006  loss: 1.2262 (1.2314)  time: 1.9304  data: 0.2310  max mem: 3717
# Epoch: [0]  [2/5]  eta: 0:00:04  lr: 0.006004  loss: 1.2243 (1.2290)  time: 1.4306  data: 0.1558  max mem: 3718
# Epoch: [0]  [3/5]  eta: 0:00:02  lr: 0.008002  loss: 1.2063 (1.2234)  time: 1.1704  data: 0.1180  max mem: 3718
# ...

# %% [markdown]
# ### 双对比

# %%
# mIOU 72.7 -> 73.6

# !CUDA_VISIBLE_DEVICES=3,6 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4 --amp   --sync_bn False \
                                    --model_name DCNet \
                                    --epochs 200 \
                                    --with_contrast 40 \
                                    --loss_name double \
                                    --layer_loss 0.1 0.1 0.05 0.01 \
                                2>&1 | tee ./output/output.log 

# 层内对比可能有损训练的精度
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=200, sync_bn=False, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DCNet', loss_name='double', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# ...

# %%
# mIOU 73.6 -> 79.8

# !CUDA_VISIBLE_DEVICES=3,6 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4 --amp --sync_bn False \
                                    --model_name DCNet\
                                    --epochs 1000 \ 
                                    --with_contrast 40 \
                                    --loss_name double \
                                    --layer_loss 0.1 0.1 0.05 0.01 \
                                2>&1 | tee ./output/output.log 
# 增大epoch 200->1000
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 1): env://
# | distributed init (rank 0): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=1000, sync_bn=False, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DCNet', loss_name='double', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# ...

# %%
# mIOU 72.7 -> 79.8

# !CUDA_VISIBLE_DEVICES=2,3 torchrun --nproc_per_node=2 \
                train_multi_GPU.py --b 4  --amp --sync_bn True \
                                    --model_name DCNet \
                                    --epochs 1000  \
                                    --with_contrast 40 \
                                    --loss_name double\
                                    --layer_loss 0.1 0.1 0.05 0.01 \
                                2>&1 | tee ./output/output.log 
# 增大epoch 200->1000、设置不同GPU上的捡BN同步
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# | distributed init (rank 0): env://
# | distributed init (rank 1): env://
# Namespace(data_path='../../../input/drive', device='cuda', num_classes=1, batch_size=4, start_epoch=0, epochs=1000, sync_bn=True, workers=4, lr=0.01, momentum=0.9, weight_decay=0.0001, save_best=True, print_freq=1, output_dir='./multi_train', resume='', test_only=False, world_size=2, dist_url='env://', amp=True, layer_loss=[0.1, 0.1, 0.05, 0.01], with_contrast=40, model_name='DCNet', loss_name='double', rank=0, gpu=0, distributed=True, dist_backend='nccl')
# Creating data loaders
# Creating model
# Start training
# ...
